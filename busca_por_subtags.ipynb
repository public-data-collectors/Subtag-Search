# %%
# !pip install ahocorapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ahocorapy
#   Downloading ahocorapy-1.6.1-py2.py3-none-any.whl (8.3 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from ahocorapy) (0.16.0)
# Installing collected packages: ahocorapy
# Successfully installed ahocorapy-1.6.1

# %% [markdown]
# ## Bibliotecas

# %%
import urllib3
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from urllib.parse import urljoin
from ahocorapy.keywordtree import KeywordTree

# %% [markdown]
# ## Extração de texto e busca por subtags

# %%
def getText(html):

    for tags in html(['script', 'style']):
        tags.decompose

    return ' '. join(html.stripped_strings)

# %%
def findPatterns(text, tree, page, df, cidade):

    results = kwtree.search_all(text)
    results = [result[0] for result in results]
    results_unique = set(results)

    for result in results_unique:
        #if results.count(result) > 1: #para exigir que resultados so sejam validos se ocorrerem mais de uma vez na pagina
        print("\"" + result + "\" found " + str(results.count(result)) + " time(s) on page: " + page)
        df.loc[cidade][result] = True
    
    if len(results) != 0:
        print("\n")

    return df

# %% [markdown]
# ## Web Crawling

# %%
def crawl(pages, depth, kwtree, df, cidade, restrictions):
    urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
    already_visited = set(pages)

    for i in range(depth):
        new_pages = set()
        print("Actual depth: " + str(i))

        for page in pages:
            http = urllib3.PoolManager()
            try:
                page_data = http.request('GET', page)
            except:
                print("Error: " + page)
                continue

            soup = BeautifulSoup(page_data.data, "lxml")
            text = getText(soup)
            df = findPatterns(text, kwtree, page, df, cidade)
            already_visited.add(page)

            links = soup.find_all('a')
            counter = 0

            for link in links:
                url = ""

                if "href" in link.attrs:
                    url = urljoin(page, str(link.get('href')))

                    if url.find("'") != -1:
                        continue

                    url = url.split("#")[0]

                is_valid = False

                # Restriction to prevent the crawler from getting out of the base URL
                for rest in restrictions[0]:
                    if url.startswith(rest):
                        is_valid = True

                for rest in restrictions[1]:
                    if rest in url:
                        is_valid = False
                        break

                if is_valid:
                    new_pages.add(url)

                counter += 1

        pages = new_pages.difference(already_visited)

    print("Number of links visited: " + str(len(already_visited)))

    return df

# %% [markdown]
# ## Criação da árvore de keywords e definição dos parâmetros de busca

# %%
kwtree = KeywordTree(case_insensitive=True)

#tags = ["Plano Plurianual", "Auxílios", "Aposentadoria", "Pensão", "Parceria", "Repasse", "Conselho", "Lei de Diretrizes", "Fiscal", "Viagens", "Resumido", "Modalidade", "Folha Pagamento", "Liquidado", "Planejamento", "Fatura", "Consolidado", "Previsto", "Arrecadado", "Concurso", "Vigencia", "Pregão Presencial", "Relatórios", "Servidores", "Obra", "Meta"]
#tags = ["Concurso","Plano", "Metas", "Terceiro setor", "Repasse", "Servidor", "Parceria"]
#tags = ["12.527/2011", "45.969/2012", "www.transparencia.mg.gov.br", " Lei de Acesso à Informação", "CODEMA", "CMDCA"]
tags = ["Transparência", "12.527/2011", "45.969/2012", "www.transparencia.mg.gov.br", "Lei de Acesso à Informação", "CODEMA", "CMDCA", "F.A.Q", "FAQ", "Perguntas Frequentes", "Pedidos", "Estrutura Organizacional", "Endereço", "Telefone", "Horário de Atendimento", "Conselhos Municipais", "Receitas", "Consolidado", "Liquida", "Previs", "Arrecada", "Classificação","Balanço", "Contas", "Meta", "Plano de Metas", "Gestão fiscal", "Resumido de Execução", "Diretrizes", "Orçament",  "Pagamentos", "Pagar", "Empenhos", "N° de empenho", "N° do empenho", "Valor", "Favorecido", "Licitaç", "Status", "Modalidade", "Resultado", "Status","Contrato", "Vigência", "Terceiro Setor", "Parcerias", "Repasses", "Data de celebração", "Data", "Conveniado", "Origem", "Recurso", "Concurso", "Conselho", "Pensão", "Plano Plurianual", "Concurso Público", "Obra", "Situação", "Servidor", "Nome", "Cargo", "Função", "Relatorio Mensal", "Despesa com Pessoal", "Despesas com pessoal", "Aposentado", "Pensionista", "Diária", "Viagen", "Viagem", "Periodo", "Convênios", "Destino", "Motivo", "Prestação"]

for tag in tags:
    kwtree.add(tag)
kwtree.finalize()

# %%
pd.set_option('max_columns', None)

cidades_dic = {"Frei Gaspar": ["https://freigaspar.mg.gov.br/transparencia",["https://fr"], ["detalhes", "noticias"]],
               "Coroaci": ["https://coroaci.mg.gov.br/transparencia",["https://co"], ["detalhes", "noticias"]], 
               "Antônio Dias": ["https://www.antoniodias.mg.gov.br/transparencia", ["https://an"], []], 
               "Itaobim": ["https://www.itaobim.mg.gov.br/transparencia", ["https://it"], []], 
               "Caputira": ["http://www.transparenciafacil.com.br/0147902", ["https://tr"], []], 
               "Guaraciaba": ["http://www.transparenciafacil.com.br/0165702", ["https://tr"], []], 
               "Abre Campo": ["https://abrecampo-mg.portaltp.com.br/", ["https://ab"], ["consultas"]],
               "Manhuaçu": ["https://manhuacu-mg.portaltp.com.br/", ["https://ma"], ["consultas"]],
               "Perdigão": ["http://lai.memory.com.br/entidades/login/9CC4C5", ["https://la"], []],
               "Martinho Campos": ["http://lai.memory.com.br/entidades/login/9BG219", ["https://la"], []],
               "Aracitaba": ["https://pm-aracitaba.publicacao.siplanweb.com.br/",["https://pm-"], []], 
               "Cruzília": ["https://pm-cruzilia.publicacao.siplanweb.com.br/",["https://pm-"], []], 
               "Rio Doce": ["https://e-gov.betha.com.br/transparencia/01037-136/recursos.faces?mun=QEEEuPpMRS0=", ["https://e-gov.be"],[]],
               "Alterosa": ["https://transparencia.betha.cloud/#/uA12YSnItzDDIAE8NxlsTA==", ["https://tra"],[]],
               "Bonito de Minas": ["http://cidadesmg.com.br/portaltransparencia/faces/user/portal.xhtml?Param=BonitoDeMinas", ["http://ci"],[]],
               "Gameleiras": ["http://cidadesmg.com.br/portaltransparencia/faces/user/portal.xhtml?Param=Gameleiras", ["http://ci"],[]],
               "Vespasiano": ["http://esic.vespasiano.mg.gov.br/Home/Index/", ["http://esic"],["Download", "VisualizarArquivo", "Detalhes", "Index"]],
               "Serranos": ["http://transparencia.serranos.mg.gov.br/", ["http://tra"],["Download", "VisualizarArquivo", "Detalhes", "Index"]],
               "Tiradentes": ["https://ptn.tiradentes.mg.gov.br/",["https://ptn"],[]],
               "Ritápolis": ["https://pt.ritapolis.mg.gov.br", ["https://pt"],[]],
               "Nova União": ["http://www.adpmnet.com.br/index.php?option=com_contpubl&idorg=26&tpform=1", ["http://www.adpmnet"],[]],
               "Serro": ["http://www.adpmnet.com.br/index.php?option=com_contpubl&idorg=139&tpform=1", ["http://www.adpmnet"],[]],
               "Elói Mendes" : ["https://www.municipalnet.com.br/index/?uid=eloi-mendes", ["https://www.muni"], []],
               "Congonhal" : ["https://www.municipalnet.com.br/index/?uid=congonhal", ["https://www.muni"], []],
               "Conquista" : ["http://portal.conquista.mg.gov.br:8080/portalcidadao/", ["http://po"], []],
               "Divinópolis" : ["https://cidadao.divinopolis.mg.gov.br/portalcidadao/", ["https://cid"], []],
               "Belo Horizonte" : ["https://transparencia.pbh.gov.br/bh_prd_transparencia/web/", ["https://tran", "https://pre"], []],
               "Itamonte" : ["http://transparencia.itamonte.mg.gov.br/", ["https://tran"], []],
               "Conceição das Alagoas" : ["http://187.72.75.161:8444/transparencia/", ["http://187"], []],
               "Rio Paranaíba" : ["http://prefriopara.ddns.net:8444/transparencia/", ["http://pre"], []]}

cidades = cidades_dic.keys()

df = pd.DataFrame(False, index = cidades, columns = tags)

df_templates = pd.DataFrame(index = cidades, columns = ["Template"]);

df_templates.loc['Frei Gaspar']["Template"] = "Template 2" 
df_templates.loc['Coroaci']["Template"] = "Template 2"  
df_templates.loc['Antônio Dias']["Template"] = "Portal Fácil (60)" 
df_templates.loc['Itaobim']["Template"] = "Portal Fácil (60)" 
df_templates.loc['Caputira']["Template"] = "Portal Fácil (46)" 
df_templates.loc['Guaraciaba']["Template"] = "Portal Fácil (46)" 
df_templates.loc['Abre Campo']["Template"] = "Portal TP" 
df_templates.loc['Manhuaçu']["Template"] = "Portal TP" 
df_templates.loc['Perdigão']["Template"] = "Memory" 
df_templates.loc['Martinho Campos']["Template"] = "Memory" 
df_templates.loc['Rio Doce']["Template"] = "Betha"
df_templates.loc['Alterosa']["Template"] = "Betha"
df_templates.loc['Aracitaba']["Template"] = "Siplanweb"
df_templates.loc['Cruzília']["Template"] = "Siplanweb"
df_templates.loc['Bonito de Minas']["Template"] = "Sintese e Tecnologia"  
df_templates.loc['Gameleiras']["Template"] = "Sintese e Tecnologia"  
df_templates.loc['Vespasiano']["Template"] = "ABO"
df_templates.loc['Serranos']["Template"] = "ABO"
df_templates.loc['Tiradentes']["Template"] = "PT"
df_templates.loc['Ritápolis']["Template"] = "PT"
df_templates.loc['Nova União']["Template"] = "ADPM"
df_templates.loc['Serro']["Template"] = "ADPM"
df_templates.loc['Elói Mendes']["Template"] = "Municipal Net"
df_templates.loc['Congonhal']["Template"] = "Municipal Net"
df_templates.loc['Conquista']["Template"] = "GRP"
df_templates.loc['Divinópolis']["Template"] = "GRP"
df_templates.loc['Belo Horizonte']["Template"] = "Template 1 (9)"
df_templates.loc['Itamonte']["Template"] = "Template 1 (9)"
df_templates.loc['Conceição das Alagoas']["Template"] = "Template 1 (22)"
df_templates.loc['Rio Paranaíba']["Template"] = "Template 1 (22)"

# %%
df
# Out:
#                        Transparência  12.527/2011  45.969/2012  \
# Frei Gaspar                    False        False        False
# Coroaci                        False        False        False
# Antônio Dias                   False        False        False
# Itaobim                        False        False        False
# Caputira                       False        False        False
# Guaraciaba                     False        False        False
# Abre Campo                     False        False        False
# Manhuaçu                       False        False        False
# Perdigão                       False        False        False
# Martinho Campos                False        False        False
# Aracitaba                      False        False        False
# Cruzília                       False        False        False
# Rio Doce                       False        False        False
# Alterosa                       False        False        False
# Bonito de Minas                False        False        False
# Gameleiras                     False        False        False
# Vespasiano                     False        False        False
# Serranos                       False        False        False
# Tiradentes                     False        False        False
# Ritápolis                      False        False        False
# Nova União                     False        False        False
# Serro                          False        False        False
# Elói Mendes                    False        False        False
# Congonhal                      False        False        False
# Conquista                      False        False        False
# Divinópolis                    False        False        False
# Belo Horizonte                 False        False        False
# Itamonte                       False        False        False
# Conceição das Alagoas          False        False        False
# Rio Paranaíba                  False        False        False
#
#                        www.transparencia.mg.gov.br  \
# Frei Gaspar                                  False
# Coroaci                                      False
# Antônio Dias                                 False
# Itaobim                                      False
# Caputira                                     False
# Guaraciaba                                   False
# Abre Campo                                   False
# Manhuaçu                                     False
# Perdigão                                     False
# Martinho Campos                              False
# Aracitaba                                    False
# Cruzília                                     False
# Rio Doce                                     False
# Alterosa                                     False
# Bonito de Minas                              False
# Gameleiras                                   False
# Vespasiano                                   False
# Serranos                                     False
# Tiradentes                                   False
# Ritápolis                                    False
# Nova União                                   False
# Serro                                        False
# Elói Mendes                                  False
# Congonhal                                    False
# Conquista                                    False
# Divinópolis                                  False
# Belo Horizonte                               False
# Itamonte                                     False
# Conceição das Alagoas                        False
# Rio Paranaíba                                False
#
#                        Lei de Acesso à Informação  CODEMA  CMDCA  F.A.Q  \
# Frei Gaspar                                 False   False  False  False
# Coroaci                                     False   False  False  False
# Antônio Dias                                False   False  False  False
# Itaobim                                     False   False  False  False
# Caputira                                    False   False  False  False
# Guaraciaba                                  False   False  False  False
# Abre Campo                                  False   False  False  False
# Manhuaçu                                    False   False  False  False
# Perdigão                                    False   False  False  False
# Martinho Campos                             False   False  False  False
# Aracitaba                                   False   False  False  False
# Cruzília                                    False   False  False  False
# Rio Doce                                    False   False  False  False
# Alterosa                                    False   False  False  False
# Bonito de Minas                             False   False  False  False
# Gameleiras                                  False   False  False  False
# Vespasiano                                  False   False  False  False
# Serranos                                    False   False  False  False
# Tiradentes                                  False   False  False  False
# Ritápolis                                   False   False  False  False
# Nova União                                  False   False  False  False
# Serro                                       False   False  False  False
# Elói Mendes                                 False   False  False  False
# Congonhal                                   False   False  False  False
# Conquista                                   False   False  False  False
# Divinópolis                                 False   False  False  False
# Belo Horizonte                              False   False  False  False
# Itamonte                                    False   False  False  False
# Conceição das Alagoas                       False   False  False  False
# Rio Paranaíba                               False   False  False  False
#
#                          FAQ  Perguntas Frequentes  Pedidos  \
# Frei Gaspar            False                 False    False
# Coroaci                False                 False    False
# Antônio Dias           False                 False    False
# Itaobim                False                 False    False
# Caputira               False                 False    False
# Guaraciaba             False                 False    False
# Abre Campo             False                 False    False
# Manhuaçu               False                 False    False
# Perdigão               False                 False    False
# Martinho Campos        False                 False    False
# Aracitaba              False                 False    False
# Cruzília               False                 False    False
# Rio Doce               False                 False    False
# Alterosa               False                 False    False
# Bonito de Minas        False                 False    False
# Gameleiras             False                 False    False
# Vespasiano             False                 False    False
# Serranos               False                 False    False
# Tiradentes             False                 False    False
# Ritápolis              False                 False    False
# Nova União             False                 False    False
# Serro                  False                 False    False
# Elói Mendes            False                 False    False
# Congonhal              False                 False    False
# Conquista              False                 False    False
# Divinópolis            False                 False    False
# Belo Horizonte         False                 False    False
# Itamonte               False                 False    False
# Conceição das Alagoas  False                 False    False
# Rio Paranaíba          False                 False    False
#
#                        Estrutura Organizacional  Endereço  Telefone  \
# Frei Gaspar                               False     False     False
# Coroaci                                   False     False     False
# Antônio Dias                              False     False     False
# Itaobim                                   False     False     False
# Caputira                                  False     False     False
# Guaraciaba                                False     False     False
# Abre Campo                                False     False     False
# Manhuaçu                                  False     False     False
# Perdigão                                  False     False     False
# Martinho Campos                           False     False     False
# Aracitaba                                 False     False     False
# Cruzília                                  False     False     False
# Rio Doce                                  False     False     False
# Alterosa                                  False     False     False
# Bonito de Minas                           False     False     False
# Gameleiras                                False     False     False
# Vespasiano                                False     False     False
# Serranos                                  False     False     False
# Tiradentes                                False     False     False
# Ritápolis                                 False     False     False
# Nova União                                False     False     False
# Serro                                     False     False     False
# Elói Mendes                               False     False     False
# Congonhal                                 False     False     False
# Conquista                                 False     False     False
# Divinópolis                               False     False     False
# Belo Horizonte                            False     False     False
# Itamonte                                  False     False     False
# Conceição das Alagoas                     False     False     False
# Rio Paranaíba                             False     False     False
#
#                        Horário de Atendimento  Conselhos Municipais  Receitas  \
# Frei Gaspar                             False                 False     False
# Coroaci                                 False                 False     False
# Antônio Dias                            False                 False     False
# Itaobim                                 False                 False     False
# Caputira                                False                 False     False
# Guaraciaba                              False                 False     False
# Abre Campo                              False                 False     False
# Manhuaçu                                False                 False     False
# Perdigão                                False                 False     False
# Martinho Campos                         False                 False     False
# Aracitaba                               False                 False     False
# Cruzília                                False                 False     False
# Rio Doce                                False                 False     False
# Alterosa                                False                 False     False
# Bonito de Minas                         False                 False     False
# Gameleiras                              False                 False     False
# Vespasiano                              False                 False     False
# Serranos                                False                 False     False
# Tiradentes                              False                 False     False
# Ritápolis                               False                 False     False
# Nova União                              False                 False     False
# Serro                                   False                 False     False
# Elói Mendes                             False                 False     False
# Congonhal                               False                 False     False
# Conquista                               False                 False     False
# Divinópolis                             False                 False     False
# Belo Horizonte                          False                 False     False
# Itamonte                                False                 False     False
# Conceição das Alagoas                   False                 False     False
# Rio Paranaíba                           False                 False     False
#
#                        Consolidado  Liquida  Previs  Arrecada  Classificação  \
# Frei Gaspar                  False    False   False     False          False
# Coroaci                      False    False   False     False          False
# Antônio Dias                 False    False   False     False          False
# Itaobim                      False    False   False     False          False
# Caputira                     False    False   False     False          False
# Guaraciaba                   False    False   False     False          False
# Abre Campo                   False    False   False     False          False
# Manhuaçu                     False    False   False     False          False
# Perdigão                     False    False   False     False          False
# Martinho Campos              False    False   False     False          False
# Aracitaba                    False    False   False     False          False
# Cruzília                     False    False   False     False          False
# Rio Doce                     False    False   False     False          False
# Alterosa                     False    False   False     False          False
# Bonito de Minas              False    False   False     False          False
# Gameleiras                   False    False   False     False          False
# Vespasiano                   False    False   False     False          False
# Serranos                     False    False   False     False          False
# Tiradentes                   False    False   False     False          False
# Ritápolis                    False    False   False     False          False
# Nova União                   False    False   False     False          False
# Serro                        False    False   False     False          False
# Elói Mendes                  False    False   False     False          False
# Congonhal                    False    False   False     False          False
# Conquista                    False    False   False     False          False
# Divinópolis                  False    False   False     False          False
# Belo Horizonte               False    False   False     False          False
# Itamonte                     False    False   False     False          False
# Conceição das Alagoas        False    False   False     False          False
# Rio Paranaíba                False    False   False     False          False
#
#                        Balanço  Contas   Meta  Plano de Metas  Gestão fiscal  \
# Frei Gaspar              False   False  False           False          False
# Coroaci                  False   False  False           False          False
# Antônio Dias             False   False  False           False          False
# Itaobim                  False   False  False           False          False
# Caputira                 False   False  False           False          False
# Guaraciaba               False   False  False           False          False
# Abre Campo               False   False  False           False          False
# Manhuaçu                 False   False  False           False          False
# Perdigão                 False   False  False           False          False
# Martinho Campos          False   False  False           False          False
# Aracitaba                False   False  False           False          False
# Cruzília                 False   False  False           False          False
# Rio Doce                 False   False  False           False          False
# Alterosa                 False   False  False           False          False
# Bonito de Minas          False   False  False           False          False
# Gameleiras               False   False  False           False          False
# Vespasiano               False   False  False           False          False
# Serranos                 False   False  False           False          False
# Tiradentes               False   False  False           False          False
# Ritápolis                False   False  False           False          False
# Nova União               False   False  False           False          False
# Serro                    False   False  False           False          False
# Elói Mendes              False   False  False           False          False
# Congonhal                False   False  False           False          False
# Conquista                False   False  False           False          False
# Divinópolis              False   False  False           False          False
# Belo Horizonte           False   False  False           False          False
# Itamonte                 False   False  False           False          False
# Conceição das Alagoas    False   False  False           False          False
# Rio Paranaíba            False   False  False           False          False
#
#                        Resumido de Execução  Diretrizes  Orçament  Pagamentos  \
# Frei Gaspar                           False       False     False       False
# Coroaci                               False       False     False       False
# Antônio Dias                          False       False     False       False
# Itaobim                               False       False     False       False
# Caputira                              False       False     False       False
# Guaraciaba                            False       False     False       False
# Abre Campo                            False       False     False       False
# Manhuaçu                              False       False     False       False
# Perdigão                              False       False     False       False
# Martinho Campos                       False       False     False       False
# Aracitaba                             False       False     False       False
# Cruzília                              False       False     False       False
# Rio Doce                              False       False     False       False
# Alterosa                              False       False     False       False
# Bonito de Minas                       False       False     False       False
# Gameleiras                            False       False     False       False
# Vespasiano                            False       False     False       False
# Serranos                              False       False     False       False
# Tiradentes                            False       False     False       False
# Ritápolis                             False       False     False       False
# Nova União                            False       False     False       False
# Serro                                 False       False     False       False
# Elói Mendes                           False       False     False       False
# Congonhal                             False       False     False       False
# Conquista                             False       False     False       False
# Divinópolis                           False       False     False       False
# Belo Horizonte                        False       False     False       False
# Itamonte                              False       False     False       False
# Conceição das Alagoas                 False       False     False       False
# Rio Paranaíba                         False       False     False       False
#
#                        Pagar  Empenhos  N° de empenho  N° do empenho  Valor  \
# Frei Gaspar            False     False          False          False  False
# Coroaci                False     False          False          False  False
# Antônio Dias           False     False          False          False  False
# Itaobim                False     False          False          False  False
# Caputira               False     False          False          False  False
# Guaraciaba             False     False          False          False  False
# Abre Campo             False     False          False          False  False
# Manhuaçu               False     False          False          False  False
# Perdigão               False     False          False          False  False
# Martinho Campos        False     False          False          False  False
# Aracitaba              False     False          False          False  False
# Cruzília               False     False          False          False  False
# Rio Doce               False     False          False          False  False
# Alterosa               False     False          False          False  False
# Bonito de Minas        False     False          False          False  False
# Gameleiras             False     False          False          False  False
# Vespasiano             False     False          False          False  False
# Serranos               False     False          False          False  False
# Tiradentes             False     False          False          False  False
# Ritápolis              False     False          False          False  False
# Nova União             False     False          False          False  False
# Serro                  False     False          False          False  False
# Elói Mendes            False     False          False          False  False
# Congonhal              False     False          False          False  False
# Conquista              False     False          False          False  False
# Divinópolis            False     False          False          False  False
# Belo Horizonte         False     False          False          False  False
# Itamonte               False     False          False          False  False
# Conceição das Alagoas  False     False          False          False  False
# Rio Paranaíba          False     False          False          False  False
#
#                        Favorecido  Licitaç  Status  Modalidade  Resultado  \
# Frei Gaspar                 False    False   False       False      False
# Coroaci                     False    False   False       False      False
# Antônio Dias                False    False   False       False      False
# Itaobim                     False    False   False       False      False
# Caputira                    False    False   False       False      False
# Guaraciaba                  False    False   False       False      False
# Abre Campo                  False    False   False       False      False
# Manhuaçu                    False    False   False       False      False
# Perdigão                    False    False   False       False      False
# Martinho Campos             False    False   False       False      False
# Aracitaba                   False    False   False       False      False
# Cruzília                    False    False   False       False      False
# Rio Doce                    False    False   False       False      False
# Alterosa                    False    False   False       False      False
# Bonito de Minas             False    False   False       False      False
# Gameleiras                  False    False   False       False      False
# Vespasiano                  False    False   False       False      False
# Serranos                    False    False   False       False      False
# Tiradentes                  False    False   False       False      False
# Ritápolis                   False    False   False       False      False
# Nova União                  False    False   False       False      False
# Serro                       False    False   False       False      False
# Elói Mendes                 False    False   False       False      False
# Congonhal                   False    False   False       False      False
# Conquista                   False    False   False       False      False
# Divinópolis                 False    False   False       False      False
# Belo Horizonte              False    False   False       False      False
# Itamonte                    False    False   False       False      False
# Conceição das Alagoas       False    False   False       False      False
# Rio Paranaíba               False    False   False       False      False
#
#                        Status  Contrato  Vigência  Terceiro Setor  Parcerias  \
# Frei Gaspar             False     False     False           False      False
# Coroaci                 False     False     False           False      False
# Antônio Dias            False     False     False           False      False
# Itaobim                 False     False     False           False      False
# Caputira                False     False     False           False      False
# Guaraciaba              False     False     False           False      False
# Abre Campo              False     False     False           False      False
# Manhuaçu                False     False     False           False      False
# Perdigão                False     False     False           False      False
# Martinho Campos         False     False     False           False      False
# Aracitaba               False     False     False           False      False
# Cruzília                False     False     False           False      False
# Rio Doce                False     False     False           False      False
# Alterosa                False     False     False           False      False
# Bonito de Minas         False     False     False           False      False
# Gameleiras              False     False     False           False      False
# Vespasiano              False     False     False           False      False
# Serranos                False     False     False           False      False
# Tiradentes              False     False     False           False      False
# Ritápolis               False     False     False           False      False
# Nova União              False     False     False           False      False
# Serro                   False     False     False           False      False
# Elói Mendes             False     False     False           False      False
# Congonhal               False     False     False           False      False
# Conquista               False     False     False           False      False
# Divinópolis             False     False     False           False      False
# Belo Horizonte          False     False     False           False      False
# Itamonte                False     False     False           False      False
# Conceição das Alagoas   False     False     False           False      False
# Rio Paranaíba           False     False     False           False      False
#
#                        Repasses  Data de celebração   Data  Conveniado  \
# Frei Gaspar               False               False  False       False
# Coroaci                   False               False  False       False
# Antônio Dias              False               False  False       False
# Itaobim                   False               False  False       False
# Caputira                  False               False  False       False
# Guaraciaba                False               False  False       False
# Abre Campo                False               False  False       False
# Manhuaçu                  False               False  False       False
# Perdigão                  False               False  False       False
# Martinho Campos           False               False  False       False
# Aracitaba                 False               False  False       False
# Cruzília                  False               False  False       False
# Rio Doce                  False               False  False       False
# Alterosa                  False               False  False       False
# Bonito de Minas           False               False  False       False
# Gameleiras                False               False  False       False
# Vespasiano                False               False  False       False
# Serranos                  False               False  False       False
# Tiradentes                False               False  False       False
# Ritápolis                 False               False  False       False
# Nova União                False               False  False       False
# Serro                     False               False  False       False
# Elói Mendes               False               False  False       False
# Congonhal                 False               False  False       False
# Conquista                 False               False  False       False
# Divinópolis               False               False  False       False
# Belo Horizonte            False               False  False       False
# Itamonte                  False               False  False       False
# Conceição das Alagoas     False               False  False       False
# Rio Paranaíba             False               False  False       False
#
#                        Origem  Recurso  Concurso  Conselho  Pensão  \
# Frei Gaspar             False    False     False     False   False
# Coroaci                 False    False     False     False   False
# Antônio Dias            False    False     False     False   False
# Itaobim                 False    False     False     False   False
# Caputira                False    False     False     False   False
# Guaraciaba              False    False     False     False   False
# Abre Campo              False    False     False     False   False
# Manhuaçu                False    False     False     False   False
# Perdigão                False    False     False     False   False
# Martinho Campos         False    False     False     False   False
# Aracitaba               False    False     False     False   False
# Cruzília                False    False     False     False   False
# Rio Doce                False    False     False     False   False
# Alterosa                False    False     False     False   False
# Bonito de Minas         False    False     False     False   False
# Gameleiras              False    False     False     False   False
# Vespasiano              False    False     False     False   False
# Serranos                False    False     False     False   False
# Tiradentes              False    False     False     False   False
# Ritápolis               False    False     False     False   False
# Nova União              False    False     False     False   False
# Serro                   False    False     False     False   False
# Elói Mendes             False    False     False     False   False
# Congonhal               False    False     False     False   False
# Conquista               False    False     False     False   False
# Divinópolis             False    False     False     False   False
# Belo Horizonte          False    False     False     False   False
# Itamonte                False    False     False     False   False
# Conceição das Alagoas   False    False     False     False   False
# Rio Paranaíba           False    False     False     False   False
#
#                        Plano Plurianual  Concurso Público   Obra  Situação  \
# Frei Gaspar                       False             False  False     False
# Coroaci                           False             False  False     False
# Antônio Dias                      False             False  False     False
# Itaobim                           False             False  False     False
# Caputira                          False             False  False     False
# Guaraciaba                        False             False  False     False
# Abre Campo                        False             False  False     False
# Manhuaçu                          False             False  False     False
# Perdigão                          False             False  False     False
# Martinho Campos                   False             False  False     False
# Aracitaba                         False             False  False     False
# Cruzília                          False             False  False     False
# Rio Doce                          False             False  False     False
# Alterosa                          False             False  False     False
# Bonito de Minas                   False             False  False     False
# Gameleiras                        False             False  False     False
# Vespasiano                        False             False  False     False
# Serranos                          False             False  False     False
# Tiradentes                        False             False  False     False
# Ritápolis                         False             False  False     False
# Nova União                        False             False  False     False
# Serro                             False             False  False     False
# Elói Mendes                       False             False  False     False
# Congonhal                         False             False  False     False
# Conquista                         False             False  False     False
# Divinópolis                       False             False  False     False
# Belo Horizonte                    False             False  False     False
# Itamonte                          False             False  False     False
# Conceição das Alagoas             False             False  False     False
# Rio Paranaíba                     False             False  False     False
#
#                        Servidor   Nome  Cargo  Função  Relatorio Mensal  \
# Frei Gaspar               False  False  False   False             False
# Coroaci                   False  False  False   False             False
# Antônio Dias              False  False  False   False             False
# Itaobim                   False  False  False   False             False
# Caputira                  False  False  False   False             False
# Guaraciaba                False  False  False   False             False
# Abre Campo                False  False  False   False             False
# Manhuaçu                  False  False  False   False             False
# Perdigão                  False  False  False   False             False
# Martinho Campos           False  False  False   False             False
# Aracitaba                 False  False  False   False             False
# Cruzília                  False  False  False   False             False
# Rio Doce                  False  False  False   False             False
# Alterosa                  False  False  False   False             False
# Bonito de Minas           False  False  False   False             False
# Gameleiras                False  False  False   False             False
# Vespasiano                False  False  False   False             False
# Serranos                  False  False  False   False             False
# Tiradentes                False  False  False   False             False
# Ritápolis                 False  False  False   False             False
# Nova União                False  False  False   False             False
# Serro                     False  False  False   False             False
# Elói Mendes               False  False  False   False             False
# Congonhal                 False  False  False   False             False
# Conquista                 False  False  False   False             False
# Divinópolis               False  False  False   False             False
# Belo Horizonte            False  False  False   False             False
# Itamonte                  False  False  False   False             False
# Conceição das Alagoas     False  False  False   False             False
# Rio Paranaíba             False  False  False   False             False
#
#                        Despesa com Pessoal  Despesas com pessoal  Aposentado  \
# Frei Gaspar                          False                 False       False
# Coroaci                              False                 False       False
# Antônio Dias                         False                 False       False
# Itaobim                              False                 False       False
# Caputira                             False                 False       False
# Guaraciaba                           False                 False       False
# Abre Campo                           False                 False       False
# Manhuaçu                             False                 False       False
# Perdigão                             False                 False       False
# Martinho Campos                      False                 False       False
# Aracitaba                            False                 False       False
# Cruzília                             False                 False       False
# Rio Doce                             False                 False       False
# Alterosa                             False                 False       False
# Bonito de Minas                      False                 False       False
# Gameleiras                           False                 False       False
# Vespasiano                           False                 False       False
# Serranos                             False                 False       False
# Tiradentes                           False                 False       False
# Ritápolis                            False                 False       False
# Nova União                           False                 False       False
# Serro                                False                 False       False
# Elói Mendes                          False                 False       False
# Congonhal                            False                 False       False
# Conquista                            False                 False       False
# Divinópolis                          False                 False       False
# Belo Horizonte                       False                 False       False
# Itamonte                             False                 False       False
# Conceição das Alagoas                False                 False       False
# Rio Paranaíba                        False                 False       False
#
#                        Pensionista  Diária  Viagen  Viagem  Periodo  \
# Frei Gaspar                  False   False   False   False    False
# Coroaci                      False   False   False   False    False
# Antônio Dias                 False   False   False   False    False
# Itaobim                      False   False   False   False    False
# Caputira                     False   False   False   False    False
# Guaraciaba                   False   False   False   False    False
# Abre Campo                   False   False   False   False    False
# Manhuaçu                     False   False   False   False    False
# Perdigão                     False   False   False   False    False
# Martinho Campos              False   False   False   False    False
# Aracitaba                    False   False   False   False    False
# Cruzília                     False   False   False   False    False
# Rio Doce                     False   False   False   False    False
# Alterosa                     False   False   False   False    False
# Bonito de Minas              False   False   False   False    False
# Gameleiras                   False   False   False   False    False
# Vespasiano                   False   False   False   False    False
# Serranos                     False   False   False   False    False
# Tiradentes                   False   False   False   False    False
# Ritápolis                    False   False   False   False    False
# Nova União                   False   False   False   False    False
# Serro                        False   False   False   False    False
# Elói Mendes                  False   False   False   False    False
# Congonhal                    False   False   False   False    False
# Conquista                    False   False   False   False    False
# Divinópolis                  False   False   False   False    False
# Belo Horizonte               False   False   False   False    False
# Itamonte                     False   False   False   False    False
# Conceição das Alagoas        False   False   False   False    False
# Rio Paranaíba                False   False   False   False    False
#
#                        Convênios  Destino  Motivo  Prestação
# Frei Gaspar                False    False   False      False
# Coroaci                    False    False   False      False
# Antônio Dias               False    False   False      False
# Itaobim                    False    False   False      False
# Caputira                   False    False   False      False
# Guaraciaba                 False    False   False      False
# Abre Campo                 False    False   False      False
# Manhuaçu                   False    False   False      False
# Perdigão                   False    False   False      False
# Martinho Campos            False    False   False      False
# Aracitaba                  False    False   False      False
# Cruzília                   False    False   False      False
# Rio Doce                   False    False   False      False
# Alterosa                   False    False   False      False
# Bonito de Minas            False    False   False      False
# Gameleiras                 False    False   False      False
# Vespasiano                 False    False   False      False
# Serranos                   False    False   False      False
# Tiradentes                 False    False   False      False
# Ritápolis                  False    False   False      False
# Nova União                 False    False   False      False
# Serro                      False    False   False      False
# Elói Mendes                False    False   False      False
# Congonhal                  False    False   False      False
# Conquista                  False    False   False      False
# Divinópolis                False    False   False      False
# Belo Horizonte             False    False   False      False
# Itamonte                   False    False   False      False
# Conceição das Alagoas      False    False   False      False
# Rio Paranaíba              False    False   False      False

# %%
df_templates
# Out:
#                                    Template
# Frei Gaspar                      Template 2
# Coroaci                          Template 2
# Antônio Dias              Portal Fácil (60)
# Itaobim                   Portal Fácil (60)
# Caputira                  Portal Fácil (46)
# Guaraciaba                Portal Fácil (46)
# Abre Campo                        Portal TP
# Manhuaçu                          Portal TP
# Perdigão                             Memory
# Martinho Campos                      Memory
# Aracitaba                         Siplanweb
# Cruzília                          Siplanweb
# Rio Doce                              Betha
# Alterosa                              Betha
# Bonito de Minas        Sintese e Tecnologia
# Gameleiras             Sintese e Tecnologia
# Vespasiano                              ABO
# Serranos                                ABO
# Tiradentes                               PT
# Ritápolis                                PT
# Nova União                             ADPM
# Serro                                  ADPM
# Elói Mendes                   Municipal Net
# Congonhal                     Municipal Net
# Conquista                               GRP
# Divinópolis                             GRP
# Belo Horizonte               Template 1 (9)
# Itamonte                     Template 1 (9)
# Conceição das Alagoas       Template 1 (22)
# Rio Paranaíba               Template 1 (22)

# %% [markdown]
# ## Execução

# %%
for key, value in cidades_dic.items():
    df = crawl([value[0]], 3, kwtree, df, key, [value[1], value[2]])

# %%
df_completo = df_templates.join(df)
df_completo
# Out:
#                                    Template  Transparência  12.527/2011  \
# Frei Gaspar                      Template 2           True         True
# Coroaci                          Template 2           True         True
# Antônio Dias              Portal Fácil (60)          False        False
# Itaobim                   Portal Fácil (60)          False        False
# Caputira                  Portal Fácil (46)           True        False
# Guaraciaba                Portal Fácil (46)           True        False
# Abre Campo                        Portal TP           True        False
# Manhuaçu                          Portal TP           True        False
# Perdigão                             Memory           True        False
# Martinho Campos                      Memory           True        False
# Aracitaba                         Siplanweb           True        False
# Cruzília                          Siplanweb           True        False
# Rio Doce                              Betha           True        False
# Alterosa                              Betha           True        False
# Bonito de Minas        Sintese e Tecnologia           True        False
# Gameleiras             Sintese e Tecnologia           True        False
# Vespasiano                              ABO           True         True
# Serranos                                ABO           True         True
# Tiradentes                               PT           True        False
# Ritápolis                                PT           True        False
# Nova União                             ADPM          False        False
# Serro                                  ADPM          False        False
# Elói Mendes                   Municipal Net          False        False
# Congonhal                     Municipal Net          False        False
# Conquista                               GRP          False        False
# Divinópolis                             GRP          False        False
# Belo Horizonte               Template 1 (9)           True        False
# Itamonte                     Template 1 (9)          False        False
# Conceição das Alagoas       Template 1 (22)           True         True
# Rio Paranaíba               Template 1 (22)           True         True
#
#                        45.969/2012  www.transparencia.mg.gov.br  \
# Frei Gaspar                  False                        False
# Coroaci                      False                        False
# Antônio Dias                 False                        False
# Itaobim                      False                        False
# Caputira                     False                        False
# Guaraciaba                   False                        False
# Abre Campo                   False                        False
# Manhuaçu                     False                        False
# Perdigão                     False                        False
# Martinho Campos              False                        False
# Aracitaba                    False                        False
# Cruzília                     False                        False
# Rio Doce                     False                        False
# Alterosa                     False                        False
# Bonito de Minas              False                        False
# Gameleiras                   False                        False
# Vespasiano                   False                        False
# Serranos                     False                        False
# Tiradentes                   False                        False
# Ritápolis                    False                        False
# Nova União                   False                        False
# Serro                        False                        False
# Elói Mendes                  False                        False
# Congonhal                    False                        False
# Conquista                    False                        False
# Divinópolis                  False                        False
# Belo Horizonte               False                        False
# Itamonte                     False                        False
# Conceição das Alagoas         True                        False
# Rio Paranaíba                False                        False
#
#                        Lei de Acesso à Informação  CODEMA  CMDCA  F.A.Q  \
# Frei Gaspar                                  True   False  False   True
# Coroaci                                      True   False  False   True
# Antônio Dias                                False   False  False  False
# Itaobim                                     False   False  False  False
# Caputira                                    False   False  False  False
# Guaraciaba                                  False   False  False  False
# Abre Campo                                   True   False  False  False
# Manhuaçu                                     True   False  False  False
# Perdigão                                    False   False  False  False
# Martinho Campos                             False   False  False  False
# Aracitaba                                   False   False  False  False
# Cruzília                                    False   False  False  False
# Rio Doce                                    False   False  False  False
# Alterosa                                    False   False  False  False
# Bonito de Minas                             False   False  False  False
# Gameleiras                                  False   False  False  False
# Vespasiano                                   True   False  False  False
# Serranos                                     True   False  False  False
# Tiradentes                                   True   False  False  False
# Ritápolis                                    True   False  False  False
# Nova União                                  False   False  False  False
# Serro                                       False    True   True  False
# Elói Mendes                                 False   False  False  False
# Congonhal                                   False   False  False  False
# Conquista                                   False   False  False  False
# Divinópolis                                 False   False  False  False
# Belo Horizonte                              False   False  False  False
# Itamonte                                    False   False  False  False
# Conceição das Alagoas                       False    True  False  False
# Rio Paranaíba                               False   False  False  False
#
#                          FAQ  Perguntas Frequentes  Pedidos  \
# Frei Gaspar            False                  True     True
# Coroaci                False                  True     True
# Antônio Dias           False                 False    False
# Itaobim                False                 False    False
# Caputira               False                 False    False
# Guaraciaba             False                 False    False
# Abre Campo             False                  True    False
# Manhuaçu               False                  True    False
# Perdigão               False                 False    False
# Martinho Campos        False                 False    False
# Aracitaba               True                 False    False
# Cruzília               False                 False    False
# Rio Doce               False                  True     True
# Alterosa               False                 False    False
# Bonito de Minas        False                 False    False
# Gameleiras             False                 False    False
# Vespasiano              True                  True     True
# Serranos                True                  True     True
# Tiradentes             False                 False    False
# Ritápolis              False                 False    False
# Nova União             False                 False    False
# Serro                  False                 False    False
# Elói Mendes            False                 False    False
# Congonhal              False                 False    False
# Conquista              False                 False    False
# Divinópolis            False                 False    False
# Belo Horizonte         False                 False    False
# Itamonte               False                 False    False
# Conceição das Alagoas  False                  True     True
# Rio Paranaíba          False                  True     True
#
#                        Estrutura Organizacional  Endereço  Telefone  \
# Frei Gaspar                                True      True      True
# Coroaci                                    True      True      True
# Antônio Dias                              False     False     False
# Itaobim                                   False     False     False
# Caputira                                  False     False     False
# Guaraciaba                                False     False     False
# Abre Campo                                 True     False     False
# Manhuaçu                                   True     False     False
# Perdigão                                  False     False     False
# Martinho Campos                           False     False     False
# Aracitaba                                 False      True     False
# Cruzília                                  False      True     False
# Rio Doce                                  False     False     False
# Alterosa                                  False     False     False
# Bonito de Minas                           False     False     False
# Gameleiras                                False     False     False
# Vespasiano                                 True      True      True
# Serranos                                   True      True      True
# Tiradentes                                False      True      True
# Ritápolis                                  True      True      True
# Nova União                                False     False     False
# Serro                                     False      True      True
# Elói Mendes                               False     False     False
# Congonhal                                 False     False     False
# Conquista                                 False     False     False
# Divinópolis                               False     False     False
# Belo Horizonte                            False     False     False
# Itamonte                                  False     False     False
# Conceição das Alagoas                      True      True     False
# Rio Paranaíba                              True      True      True
#
#                        Horário de Atendimento  Conselhos Municipais  Receitas  \
# Frei Gaspar                             False                 False      True
# Coroaci                                 False                 False      True
# Antônio Dias                            False                 False     False
# Itaobim                                 False                 False     False
# Caputira                                False                 False     False
# Guaraciaba                              False                 False     False
# Abre Campo                              False                 False      True
# Manhuaçu                                False                 False      True
# Perdigão                                False                 False     False
# Martinho Campos                         False                 False     False
# Aracitaba                               False                 False      True
# Cruzília                                False                 False      True
# Rio Doce                                False                 False      True
# Alterosa                                False                 False     False
# Bonito de Minas                         False                 False      True
# Gameleiras                              False                 False      True
# Vespasiano                               True                  True      True
# Serranos                                 True                 False      True
# Tiradentes                               True                 False      True
# Ritápolis                                True                 False      True
# Nova União                              False                 False      True
# Serro                                   False                 False      True
# Elói Mendes                             False                 False      True
# Congonhal                               False                 False      True
# Conquista                               False                 False     False
# Divinópolis                             False                 False     False
# Belo Horizonte                          False                 False     False
# Itamonte                                False                 False     False
# Conceição das Alagoas                   False                 False      True
# Rio Paranaíba                           False                 False      True
#
#                        Consolidado  Liquida  Previs  Arrecada  Classificação  \
# Frei Gaspar                  False     True   False      True          False
# Coroaci                      False     True   False      True           True
# Antônio Dias                 False    False   False     False          False
# Itaobim                      False    False   False     False          False
# Caputira                     False    False   False     False          False
# Guaraciaba                   False    False   False     False          False
# Abre Campo                    True     True    True      True          False
# Manhuaçu                      True     True    True      True          False
# Perdigão                     False    False   False     False          False
# Martinho Campos              False    False   False     False          False
# Aracitaba                     True     True    True      True          False
# Cruzília                      True     True    True      True          False
# Rio Doce                     False     True   False      True          False
# Alterosa                     False    False   False     False          False
# Bonito de Minas              False     True    True      True           True
# Gameleiras                   False     True    True      True           True
# Vespasiano                   False     True    True      True           True
# Serranos                     False     True    True      True           True
# Tiradentes                   False     True    True      True          False
# Ritápolis                    False     True    True      True          False
# Nova União                   False    False   False      True          False
# Serro                        False     True    True      True          False
# Elói Mendes                   True     True   False     False          False
# Congonhal                     True     True   False     False          False
# Conquista                    False    False   False     False          False
# Divinópolis                  False    False   False     False          False
# Belo Horizonte               False    False   False     False          False
# Itamonte                     False    False   False     False          False
# Conceição das Alagoas        False     True    True      True           True
# Rio Paranaíba                False     True    True      True           True
#
#                        Balanço  Contas   Meta  Plano de Metas  Gestão fiscal  \
# Frei Gaspar              False    True  False           False           True
# Coroaci                  False    True  False           False           True
# Antônio Dias             False   False  False           False          False
# Itaobim                  False   False  False           False          False
# Caputira                 False   False  False           False          False
# Guaraciaba               False   False  False           False          False
# Abre Campo                True    True  False           False           True
# Manhuaçu                  True    True   True           False           True
# Perdigão                 False   False  False           False          False
# Martinho Campos          False   False  False           False          False
# Aracitaba                 True    True   True           False           True
# Cruzília                  True    True   True           False           True
# Rio Doce                 False    True  False           False          False
# Alterosa                 False   False  False           False          False
# Bonito de Minas           True    True   True           False           True
# Gameleiras                True    True   True           False           True
# Vespasiano               False    True   True           False           True
# Serranos                 False    True   True           False           True
# Tiradentes                True    True   True           False          False
# Ritápolis                 True    True   True           False          False
# Nova União                True    True   True           False           True
# Serro                     True    True   True           False           True
# Elói Mendes              False    True  False           False          False
# Congonhal                False    True  False           False          False
# Conquista                False   False  False           False          False
# Divinópolis              False   False  False           False          False
# Belo Horizonte           False   False  False           False          False
# Itamonte                 False   False  False           False          False
# Conceição das Alagoas    False    True   True           False           True
# Rio Paranaíba            False    True   True           False           True
#
#                        Resumido de Execução  Diretrizes  Orçament  Pagamentos  \
# Frei Gaspar                           False        True      True        True
# Coroaci                               False        True      True        True
# Antônio Dias                          False       False     False       False
# Itaobim                               False       False     False       False
# Caputira                              False       False     False       False
# Guaraciaba                            False       False     False       False
# Abre Campo                            False        True      True        True
# Manhuaçu                              False        True      True        True
# Perdigão                              False       False     False       False
# Martinho Campos                       False       False     False       False
# Aracitaba                             False        True      True        True
# Cruzília                              False        True      True       False
# Rio Doce                              False       False      True       False
# Alterosa                              False       False     False       False
# Bonito de Minas                       False       False      True        True
# Gameleiras                            False       False      True        True
# Vespasiano                             True        True      True        True
# Serranos                               True        True      True        True
# Tiradentes                             True        True      True       False
# Ritápolis                              True        True      True       False
# Nova União                            False       False      True        True
# Serro                                 False       False      True        True
# Elói Mendes                           False       False      True        True
# Congonhal                             False       False      True        True
# Conquista                             False       False     False       False
# Divinópolis                           False       False     False       False
# Belo Horizonte                        False       False     False       False
# Itamonte                              False       False     False       False
# Conceição das Alagoas                 False        True      True        True
# Rio Paranaíba                         False        True      True        True
#
#                        Pagar  Empenhos  N° de empenho  N° do empenho  Valor  \
# Frei Gaspar            False      True          False          False   True
# Coroaci                 True      True          False          False   True
# Antônio Dias           False     False          False          False  False
# Itaobim                False     False          False          False  False
# Caputira               False     False          False          False  False
# Guaraciaba             False     False          False          False  False
# Abre Campo              True      True          False          False   True
# Manhuaçu                True      True          False          False   True
# Perdigão               False     False          False          False  False
# Martinho Campos        False     False          False          False  False
# Aracitaba               True      True          False          False   True
# Cruzília                True      True          False          False   True
# Rio Doce               False      True          False          False  False
# Alterosa               False     False          False          False  False
# Bonito de Minas         True      True          False          False   True
# Gameleiras              True      True          False          False   True
# Vespasiano              True      True          False          False   True
# Serranos                True      True          False          False   True
# Tiradentes             False     False          False          False   True
# Ritápolis              False     False          False          False   True
# Nova União              True     False          False          False  False
# Serro                   True      True          False          False   True
# Elói Mendes             True     False          False          False   True
# Congonhal               True     False          False          False   True
# Conquista              False     False          False          False  False
# Divinópolis            False     False          False          False  False
# Belo Horizonte         False     False          False          False  False
# Itamonte               False     False          False          False  False
# Conceição das Alagoas   True      True          False          False   True
# Rio Paranaíba           True      True          False          False   True
#
#                        Favorecido  Licitaç  Status  Modalidade  Resultado  \
# Frei Gaspar                 False     True    True        True       True
# Coroaci                      True     True    True        True       True
# Antônio Dias                False    False   False       False      False
# Itaobim                     False    False   False       False      False
# Caputira                    False    False   False       False      False
# Guaraciaba                  False    False   False       False      False
# Abre Campo                   True     True   False        True       True
# Manhuaçu                     True     True   False        True       True
# Perdigão                    False    False   False       False      False
# Martinho Campos             False    False   False       False      False
# Aracitaba                   False     True    True        True       True
# Cruzília                    False     True    True        True       True
# Rio Doce                     True     True   False       False      False
# Alterosa                    False    False   False       False      False
# Bonito de Minas             False     True    True        True      False
# Gameleiras                  False     True    True        True      False
# Vespasiano                   True     True   False        True       True
# Serranos                     True     True   False        True       True
# Tiradentes                  False     True   False       False       True
# Ritápolis                   False     True   False       False       True
# Nova União                  False    False   False       False       True
# Serro                       False     True    True       False       True
# Elói Mendes                  True     True    True       False       True
# Congonhal                    True     True    True       False       True
# Conquista                   False    False   False       False      False
# Divinópolis                 False    False   False       False      False
# Belo Horizonte              False     True    True       False      False
# Itamonte                    False    False   False       False      False
# Conceição das Alagoas       False     True    True        True       True
# Rio Paranaíba               False     True    True        True       True
#
#                        Status  Contrato  Vigência  Terceiro Setor  Parcerias  \
# Frei Gaspar              True      True     False           False      False
# Coroaci                  True      True     False           False      False
# Antônio Dias            False     False     False           False      False
# Itaobim                 False     False     False           False      False
# Caputira                False     False     False           False      False
# Guaraciaba              False     False     False           False      False
# Abre Campo              False      True     False           False       True
# Manhuaçu                False      True     False           False       True
# Perdigão                False     False     False           False      False
# Martinho Campos         False     False     False           False      False
# Aracitaba                True      True      True           False      False
# Cruzília                 True      True      True           False      False
# Rio Doce                False      True     False           False      False
# Alterosa                False     False     False           False      False
# Bonito de Minas          True      True     False           False      False
# Gameleiras               True      True     False           False      False
# Vespasiano              False      True     False           False       True
# Serranos                False      True     False           False       True
# Tiradentes              False      True     False           False      False
# Ritápolis               False      True     False           False      False
# Nova União              False      True     False           False      False
# Serro                    True      True     False           False      False
# Elói Mendes              True      True     False           False      False
# Congonhal                True      True     False           False      False
# Conquista               False     False     False           False      False
# Divinópolis             False     False     False           False      False
# Belo Horizonte           True     False     False           False      False
# Itamonte                False     False     False           False      False
# Conceição das Alagoas    True      True      True           False       True
# Rio Paranaíba            True      True      True           False      False
#
#                        Repasses  Data de celebração   Data  Conveniado  \
# Frei Gaspar                True                True   True       False
# Coroaci                    True               False   True       False
# Antônio Dias              False               False  False       False
# Itaobim                   False               False  False       False
# Caputira                  False               False  False       False
# Guaraciaba                False               False  False       False
# Abre Campo                 True               False   True       False
# Manhuaçu                   True               False   True       False
# Perdigão                  False               False  False       False
# Martinho Campos           False               False  False       False
# Aracitaba                  True               False   True       False
# Cruzília                   True               False   True       False
# Rio Doce                   True               False   True       False
# Alterosa                  False               False  False       False
# Bonito de Minas           False               False   True       False
# Gameleiras                False               False   True       False
# Vespasiano                 True               False   True       False
# Serranos                   True               False   True       False
# Tiradentes                False               False   True       False
# Ritápolis                 False               False   True       False
# Nova União                 True               False   True       False
# Serro                      True               False   True       False
# Elói Mendes                True               False   True       False
# Congonhal                  True               False   True       False
# Conquista                 False               False  False       False
# Divinópolis               False               False  False       False
# Belo Horizonte            False               False   True       False
# Itamonte                  False               False  False       False
# Conceição das Alagoas      True               False   True       False
# Rio Paranaíba              True               False   True       False
#
#                        Origem  Recurso  Concurso  Conselho  Pensão  \
# Frei Gaspar              True     True      True      True    True
# Coroaci                  True     True      True      True   False
# Antônio Dias            False    False     False     False   False
# Itaobim                 False    False     False     False   False
# Caputira                False    False     False     False   False
# Guaraciaba              False    False     False     False   False
# Abre Campo               True     True      True     False   False
# Manhuaçu                 True     True      True     False   False
# Perdigão                False    False     False     False   False
# Martinho Campos         False    False     False     False   False
# Aracitaba                True     True      True      True   False
# Cruzília                 True     True      True      True    True
# Rio Doce                False     True     False     False   False
# Alterosa                False    False     False     False   False
# Bonito de Minas         False     True     False      True   False
# Gameleiras              False     True     False      True   False
# Vespasiano               True     True      True      True    True
# Serranos                 True     True      True     False    True
# Tiradentes              False     True      True     False   False
# Ritápolis               False     True      True     False   False
# Nova União              False     True     False      True    True
# Serro                   False     True      True      True    True
# Elói Mendes              True     True     False     False   False
# Congonhal                True     True     False     False   False
# Conquista               False    False     False     False   False
# Divinópolis             False    False     False     False   False
# Belo Horizonte          False    False     False     False   False
# Itamonte                False    False     False     False   False
# Conceição das Alagoas    True     True      True      True   False
# Rio Paranaíba            True     True      True      True   False
#
#                        Plano Plurianual  Concurso Público   Obra  Situação  \
# Frei Gaspar                        True              True   True      True
# Coroaci                            True              True   True      True
# Antônio Dias                      False             False  False     False
# Itaobim                           False             False  False     False
# Caputira                          False             False  False     False
# Guaraciaba                        False             False  False     False
# Abre Campo                         True              True   True      True
# Manhuaçu                           True              True   True      True
# Perdigão                          False             False  False     False
# Martinho Campos                   False             False  False     False
# Aracitaba                          True             False   True      True
# Cruzília                           True             False   True      True
# Rio Doce                          False             False   True     False
# Alterosa                          False             False  False     False
# Bonito de Minas                   False             False   True      True
# Gameleiras                        False             False   True      True
# Vespasiano                         True              True   True      True
# Serranos                           True              True   True      True
# Tiradentes                         True             False   True     False
# Ritápolis                          True             False   True     False
# Nova União                        False             False   True     False
# Serro                             False              True   True      True
# Elói Mendes                       False             False  False      True
# Congonhal                         False             False  False      True
# Conquista                         False             False  False     False
# Divinópolis                       False             False  False     False
# Belo Horizonte                    False             False  False     False
# Itamonte                          False             False  False     False
# Conceição das Alagoas              True              True   True      True
# Rio Paranaíba                      True              True   True      True
#
#                        Servidor   Nome  Cargo  Função  Relatorio Mensal  \
# Frei Gaspar                True   True   True    True             False
# Coroaci                    True   True   True    True             False
# Antônio Dias              False  False  False   False             False
# Itaobim                   False  False  False   False             False
# Caputira                  False  False  False   False             False
# Guaraciaba                False  False  False   False             False
# Abre Campo                 True   True   True    True             False
# Manhuaçu                   True   True   True    True             False
# Perdigão                  False   True  False   False             False
# Martinho Campos           False   True  False   False             False
# Aracitaba                  True   True   True    True             False
# Cruzília                   True   True   True    True             False
# Rio Doce                   True   True  False   False             False
# Alterosa                  False  False  False   False             False
# Bonito de Minas            True   True   True    True             False
# Gameleiras                 True   True   True    True             False
# Vespasiano                 True   True   True    True             False
# Serranos                   True   True   True    True             False
# Tiradentes                False  False  False   False             False
# Ritápolis                 False  False  False   False             False
# Nova União                 True  False  False    True             False
# Serro                      True  False   True    True             False
# Elói Mendes               False   True   True   False             False
# Congonhal                 False   True   True   False             False
# Conquista                 False  False  False   False             False
# Divinópolis               False  False  False   False             False
# Belo Horizonte            False   True  False   False             False
# Itamonte                  False  False  False   False             False
# Conceição das Alagoas      True   True   True    True             False
# Rio Paranaíba              True   True   True    True             False
#
#                        Despesa com Pessoal  Despesas com pessoal  Aposentado  \
# Frei Gaspar                           True                  True        True
# Coroaci                               True                  True        True
# Antônio Dias                         False                 False       False
# Itaobim                              False                 False       False
# Caputira                             False                 False       False
# Guaraciaba                           False                 False       False
# Abre Campo                           False                 False       False
# Manhuaçu                             False                 False       False
# Perdigão                             False                 False       False
# Martinho Campos                      False                 False       False
# Aracitaba                             True                 False        True
# Cruzília                              True                 False        True
# Rio Doce                             False                 False       False
# Alterosa                             False                 False       False
# Bonito de Minas                      False                 False        True
# Gameleiras                           False                 False        True
# Vespasiano                            True                  True        True
# Serranos                              True                  True        True
# Tiradentes                           False                 False       False
# Ritápolis                            False                 False       False
# Nova União                           False                 False        True
# Serro                                False                 False        True
# Elói Mendes                          False                  True        True
# Congonhal                            False                  True        True
# Conquista                            False                 False       False
# Divinópolis                          False                 False       False
# Belo Horizonte                       False                 False       False
# Itamonte                             False                 False       False
# Conceição das Alagoas                 True                  True        True
# Rio Paranaíba                        False                  True        True
#
#                        Pensionista  Diária  Viagen  Viagem  Periodo  \
# Frei Gaspar                   True    True    True    True    False
# Coroaci                       True    True    True    True    False
# Antônio Dias                 False   False   False   False    False
# Itaobim                      False   False   False   False    False
# Caputira                     False   False   False   False    False
# Guaraciaba                   False   False   False   False    False
# Abre Campo                   False    True   False   False    False
# Manhuaçu                     False    True   False   False    False
# Perdigão                     False   False   False   False    False
# Martinho Campos              False   False   False   False    False
# Aracitaba                     True    True    True   False    False
# Cruzília                      True    True    True   False    False
# Rio Doce                     False    True   False   False    False
# Alterosa                     False   False   False   False    False
# Bonito de Minas               True    True   False    True    False
# Gameleiras                    True    True   False    True    False
# Vespasiano                    True    True   False    True    False
# Serranos                      True    True    True    True    False
# Tiradentes                   False    True   False    True    False
# Ritápolis                    False    True   False    True    False
# Nova União                   False    True   False   False    False
# Serro                        False    True    True    True     True
# Elói Mendes                   True    True   False   False    False
# Congonhal                     True    True   False   False    False
# Conquista                    False   False   False   False    False
# Divinópolis                  False   False   False   False    False
# Belo Horizonte               False   False   False   False    False
# Itamonte                     False   False   False   False    False
# Conceição das Alagoas         True    True   False   False    False
# Rio Paranaíba                 True    True   False   False    False
#
#                        Convênios  Destino  Motivo  Prestação
# Frei Gaspar                 True     True    True       True
# Coroaci                     True     True    True       True
# Antônio Dias               False    False   False      False
# Itaobim                    False    False   False      False
# Caputira                   False    False   False      False
# Guaraciaba                 False    False   False      False
# Abre Campo                  True    False   False       True
# Manhuaçu                    True    False   False       True
# Perdigão                   False    False   False      False
# Martinho Campos            False    False   False      False
# Aracitaba                   True    False    True       True
# Cruzília                    True    False    True       True
# Rio Doce                    True    False   False      False
# Alterosa                   False    False   False      False
# Bonito de Minas            False    False   False       True
# Gameleiras                 False    False   False       True
# Vespasiano                  True    False   False       True
# Serranos                    True    False    True       True
# Tiradentes                  True    False   False       True
# Ritápolis                   True    False   False       True
# Nova União                 False     True   False       True
# Serro                       True     True    True       True
# Elói Mendes                 True    False   False      False
# Congonhal                   True    False   False      False
# Conquista                  False    False   False      False
# Divinópolis                False    False   False      False
# Belo Horizonte             False    False   False      False
# Itamonte                   False    False   False      False
# Conceição das Alagoas       True     True    True       True
# Rio Paranaíba               True     True    True       True

# %% [markdown]
# ## Juntar resultados para indicar resposta por template

# %%
def merge_found_values(x):
    results = []
    l = [False] * (x.shape[0])

    for i, line in enumerate(x):
        for element in line:
            l[i] = element or l[i]

    for n in range(0, len(l), 2):
        results.append(l[n] or l[n + 1])

    return np.array(results).T

# %%
templates = ['Template 2',
       'Porta Fácil (60)',
       'Porta Fácil (46)',
       'Portla TP',
       'Memory',
       'Siplanweb',
       'Betha',
       'Sintese e Tecnologia',
       'ABO',
       'PT',
       'ADPM',
       'Municipal Net',
       'GRP',
       'Template 1 (9)',
       'Template 1 (22)']

subtags = ["Informações", "Licitações", "Empenhos", "Pagamentos", "Relatorios", 'Leis Orçamentárias', "Contas Públicas", "Contratos", "Concurso Publico", "Receitas","Terceiro Setor", "Orçamento", "Obras", "Servidores" , "Diárias", "Estrutura Organizacional", "Plano de Metas"]
df_resultados = pd.DataFrame(index = templates)

df_resultados["Informações"] = 	merge_found_values(df_completo[["Transparência", "12.527/2011", "45.969/2012",	"www.transparencia.mg.gov.br",	"Lei de Acesso à Informação",	"CODEMA",	"CMDCA",	"F.A.Q", "FAQ",	"Perguntas Frequentes",	"Pedidos",	"Estrutura Organizacional",	"Endereço",	"Telefone",	"Horário de Atendimento",	"Conselhos Municipais"]].to_numpy())	
df_resultados["Licitações"] = merge_found_values(df_completo[["Licitaç"]].to_numpy())	
df_resultados["Empenhos"] = merge_found_values(df_completo[["Empenhos",	"N° de empenho",	"N° do empenho"]].to_numpy())
df_resultados["Pagamentos"] = merge_found_values(df_completo[["Pagamentos", "Pagar"]].to_numpy())
df_resultados["Relatorios"] = merge_found_values(df_completo[["Gestão fiscal", 	"Resumido de Execução" ]].to_numpy())
df_resultados["Leis Orçamentárias"] = merge_found_values(df_completo[["Plano Plurianual",  "Diretrizes",	"Orçament"]].to_numpy())
df_resultados["Contas Públicas"] = merge_found_values(df_completo[[ "Balanço", "Contas", "Prestação"	]].to_numpy())
df_resultados["Contratos"] = merge_found_values(df_completo[["Contrato","Vigência"]].to_numpy())
df_resultados["Concurso Publico"] = merge_found_values(df_completo[["Concurso", "Concurso Público"]].to_numpy())
df_resultados["Receitas"] = merge_found_values(df_completo[["Receitas",	"Consolidado", "Liquida",	"Previs",	"Arrecada"]].to_numpy())
df_resultados["Terceiro Setor"] = merge_found_values(df_completo[["Terceiro Setor",	"Parcerias",	"Repasses", "Convênios"]].to_numpy())
df_resultados["Orçamento"] = merge_found_values(df_completo[["Orçament"]].to_numpy())
df_resultados["Servidores"] = merge_found_values(df_completo[["Servidor", "Relatorio Mensal",	"Despesa com Pessoal",	"Despesas com pessoal"]].to_numpy())
df_resultados["Diárias"] = merge_found_values(df_completo[["Diária", "Viagen",	"Viagem",	"Destino"]].to_numpy())
df_resultados["Obras"] = merge_found_values(df_completo[["Obra"]].to_numpy())
df_resultados["Estrutura Organizacional"] = merge_found_values(df_completo[["Estrutura Organizacional"]].to_numpy())
df_resultados["Plano de Metas"] = merge_found_values(df_completo[["Meta", "Plano de Metas"]].to_numpy())

# %%
df_resultados
# Out:
#                       Informações  Licitações  Empenhos  Pagamentos  \
# Template 2                   True        True      True        True
# Porta Fácil (60)            False       False     False       False
# Porta Fácil (46)             True       False     False       False
# Portla TP                    True        True      True        True
# Memory                       True       False     False       False
# Siplanweb                    True        True      True        True
# Betha                        True        True      True       False
# Sintese e Tecnologia         True        True      True        True
# ABO                          True        True      True        True
# PT                           True        True     False       False
# ADPM                         True        True      True        True
# Municipal Net               False        True     False        True
# GRP                         False       False     False       False
# Template 1 (9)               True        True     False       False
# Template 1 (22)              True        True      True        True
#
#                       Relatorios  Leis Orçamentárias  Contas Públicas  \
# Template 2                  True                True             True
# Porta Fácil (60)           False               False            False
# Porta Fácil (46)           False               False            False
# Portla TP                   True                True             True
# Memory                     False               False            False
# Siplanweb                   True                True             True
# Betha                      False                True             True
# Sintese e Tecnologia        True                True             True
# ABO                         True                True             True
# PT                          True                True             True
# ADPM                        True                True             True
# Municipal Net              False                True             True
# GRP                        False               False            False
# Template 1 (9)             False               False            False
# Template 1 (22)             True                True             True
#
#                       Contratos  Concurso Publico  Receitas  Terceiro Setor  \
# Template 2                 True              True      True            True
# Porta Fácil (60)          False             False     False           False
# Porta Fácil (46)          False             False     False           False
# Portla TP                  True              True      True            True
# Memory                    False             False     False           False
# Siplanweb                  True              True      True            True
# Betha                      True             False      True            True
# Sintese e Tecnologia       True             False      True           False
# ABO                        True              True      True            True
# PT                         True              True      True            True
# ADPM                       True              True      True            True
# Municipal Net              True             False      True            True
# GRP                       False             False     False           False
# Template 1 (9)            False             False     False           False
# Template 1 (22)            True              True      True            True
#
#                       Orçamento  Servidores  Diárias  Obras  \
# Template 2                 True        True     True   True
# Porta Fácil (60)          False       False    False  False
# Porta Fácil (46)          False       False    False  False
# Portla TP                  True        True     True   True
# Memory                    False       False    False  False
# Siplanweb                  True        True     True   True
# Betha                      True        True     True   True
# Sintese e Tecnologia       True        True     True   True
# ABO                        True        True     True   True
# PT                         True       False     True   True
# ADPM                       True        True     True   True
# Municipal Net              True        True     True  False
# GRP                       False       False    False  False
# Template 1 (9)            False       False    False  False
# Template 1 (22)            True        True     True   True
#
#                       Estrutura Organizacional  Plano de Metas
# Template 2                                True           False
# Porta Fácil (60)                         False           False
# Porta Fácil (46)                         False           False
# Portla TP                                 True            True
# Memory                                   False           False
# Siplanweb                                False            True
# Betha                                    False           False
# Sintese e Tecnologia                     False            True
# ABO                                       True            True
# PT                                        True            True
# ADPM                                     False            True
# Municipal Net                            False           False
# GRP                                      False           False
# Template 1 (9)                           False           False
# Template 1 (22)                           True            True

# %%
df_resultados.to_csv("resultados_templates.csv")
